# %%
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
import os
import pprint

# %%
parquet_file_path = "exports/sample/all-tickets.parquet"
# Out:
# --- Debugging Parquet File: all-tickets.parquet ---

# %%
print("\n--- Pandas DataFrame Inspection ---")
try:
    df = pd.read_parquet(parquet_file_path, engine='pyarrow')
    print("File loaded successfully into Pandas DataFrame.")

    print("\nDataFrame Head (first 5 rows):")
    display(df.head()) # Use display() in notebooks for richer output

    print("\nDataFrame Shape (rows, columns):", df.shape)
    print("\nDataFrame Columns:", df.columns.tolist())

    print("\nDataFrame Info (data types and non-null counts):")
    df.info()

    print("\nDataFrame Data Types:")
    print(df.dtypes)
    # Notice that the 'data' column (and any other complex columns) will likely be 'object' dtype.
    # This means Pandas is storing generic Python objects (dicts, lists) in those cells.

    print("\nCheck for Missing Values:")
    print(df.isnull().sum())

    # --- 4. Inspecting Nested Data (the 'data' column) ---
    if 'data' in df.columns and not df.empty:
        print("\n--- Inspecting 'data' column (nested content) ---")
        first_nested_item = df['data'].iloc[0]
        print(f"Type of content in 'data' column (first row): {type(first_nested_item)}")
        print("\nPretty print of first item in 'data' column:")
        pprint.pprint(first_nested_item)

        # You can access nested elements directly if they are dictionaries
        # For example, if your original JSON had {"id": 1, "nested_key": {"sub_key": "value"}}
        # you might access:
        # if isinstance(first_nested_item, dict) and 'your_nested_key' in first_nested_item:
        #     print("\nAccessing a specific nested key:")
        #     pprint.pprint(first_nested_item['your_nested_key'])

        # You can also sample other nested items
        if df.shape[0] > 5:
            print("\nPretty print of 5th item in 'data' column (if exists):")
            pprint.pprint(df['data'].iloc[4])

    else:
        print("\n'data' column not found or DataFrame is empty. Cannot inspect nested content.")

except Exception as e:
    print(f"\nError loading Parquet into Pandas DataFrame: {e}", file=sys.stderr)
    print("This might indicate file corruption or a specific schema issue.")
# Out:
# --- Pandas DataFrame Inspection ---
# File loaded successfully into Pandas DataFrame.
#
# DataFrame Head (first 5 rows):
#           original_file_path original_filename  \
# 0  2025/April/03/024699.json       024699.json
# 1  2025/April/03/024748.json       024748.json
# 2  2025/April/03/024416.json       024416.json
# 3  2025/April/03/024504.json       024504.json
# 4  2025/April/03/024787.json       024787.json
#
#                                                 data
# 0  {'conversations': [], 'export_version': '1.0',...
# 1  {'conversations': [], 'export_version': '1.0',...
# 2  {'conversations': [], 'export_version': '1.0',...
# 3  {'conversations': [], 'export_version': '1.0',...
# 4  {'conversations': [], 'export_version': '1.0',...
# DataFrame Shape (rows, columns): (11364, 3)
#
# DataFrame Columns: ['original_file_path', 'original_filename', 'data']
#
# DataFrame Info (data types and non-null counts):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11364 entries, 0 to 11363
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   original_file_path  11364 non-null  object
#  1   original_filename   11364 non-null  object
#  2   data                11364 non-null  object
# dtypes: object(3)
# memory usage: 133.2+ KB
#
# DataFrame Data Types:
# original_file_path    object
# original_filename     object
# data                  object
# dtype: object
#
# Check for Missing Values:
# original_file_path    0
# original_filename     0
# data                  0
# dtype: int64
#
# --- Inspecting 'data' column (nested content) ---
# Type of content in 'data' column (first row): <class 'dict'>
#
# Pretty print of first item in 'data' column:
# {'conversations': array([], dtype=object),
#  'export_version': '1.0',
#  'exported_at': '2025-06-28T03:15:37.698894',
#  'ticket': {'category': 'Conference Room',
#             'cc_emails': array([], dtype=object),
#             'created_at': '2025-03-25T11:37:38Z',
#             'custom_fields': {'business_impact': None,
#                               'change_number': None,
#                               'fedex_return_tracking': None,
#                               'fedex_tracking': None,
#                               'impacted_locations': None,
#                               'jira_url': None,
#                               'lf_on_behalf_of': None,
#                               'location': 'HYD',
#                               'major_incident_type': None,
#                               'msf_cause_code': array(['Access Request'], dtype=object),
#                               'msf_closure_code': array(['Solved (Permanently)'], dtype=object),
#                               'no_of_customers_impacted': None,
#                               'requested_date': None,
#                               'ticket_type': None,
#                               'time_zone': None,
#                               'transferred': None,
#                               'user_change_date': None,
#                               'user_change_email': None,
#                               'user_impact': None},
#             'deleted': False,
#             'department_id': 19000267440.0,
#             'description': '<div dir="ltr">\n'
#                            '<br><br><div>\n'
#                            '<div dir="ltr">---------- Forwarded message '
#                            '---------<br>From: <strong dir="auto">\'Zoom\' via '
#                            'India IT Ops AV</strong> <span dir="auto">&lt;<a '
#                            'href="mailto:India-IT-Ops-AV@schrodinger.com" '
#                            'rel="noreferrer">India-IT-Ops-AV@schrodinger.com</a>&gt;</span><br>Date: '
#                            'Tue, Mar 25, 2025 at 5:02\u202fPM<br>Subject: '
#                            '[Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - '
#                            'Prime 8 Pax (8) [BYOD, Google Meet, Zoom]) : Zoom '
#                            'room is offline<br>To:  &lt;<a '
#                            'href="mailto:india-it-ops-av@schrodinger.com" '
#                            'rel="noreferrer">india-it-ops-av@schrodinger.com</a>&gt;<br>\n'
#                            '</div>\n'
#                            '<br><br>\n'
#                            '<div>\n'
#                            'Dear Administrator,<br>\n'
#                            '<br>\n'
#                            'Room name: Hyd - Therapeutics 8 Pax (HYD-14-Hyd - '
#                            'Prime 8 Pax (8) [BYOD, Google Meet, Zoom])<br>\n'
#                            'Your Zoom Rooms status has changed: Zoom room is '
#                            'offline.<br>\n'
#                            '<br>\n'
#                            'Thank you for choosing Zoom.<br>\n'
#                            '-The Zoom Team\n'
#                            '</div>\n'
#                            '\n'
#                            '</div>\n'
#                            '<div><br></div>\n'
#                            '<div><br></div>\n'
#                            '<span>-- </span><br><div dir="ltr"><div '
#                            'dir="ltr">\n'
#                            '<div style="margin:0px 0px '
#                            '1pt;font-family:Arial;font-size:12px;color:rgb(7,55,99);line-height:1.15">\n'
#                            '<span style="font-weight:bolder">Arudra '
#                            'TirupathiRao\xa0</span>| Associate systems '
#                            'Administrator</div>\n'
#                            '<div style="margin:0px 0px '
#                            '1pt;font-family:Arial;font-size:12px;color:rgb(57,80,102);line-height:1.15"><br></div>\n'
#                            '<div '
#                            'style="margin:0px;font-family:Arial;font-size:12px;color:rgb(86,202,239);line-height:1.15">P:\xa0'
#                            '<a href="tel:9553412586" '
#                            'style="color:rgb(86,202,239);text-decoration:unset!important" '
#                            'target="_blank" rel="noreferrer">9553412586</a>\n'
#                            '</div>\n'
#                            '<div style="margin:0px 0px '
#                            '1pt;font-family:Arial;font-size:12px;color:rgb(7,55,99);line-height:1.15"><a '
#                            'href="https://schrodinger.com/" '
#                            'style="color:rgb(13,110,253)" target="_blank" '
#                            'rel="noreferrer"><img '
#                            'src="https://s3.amazonaws.com/content.schrodinger.com/images/email_sig/logo.png" '
#                            'alt="Schrödinger, Inc." height="63.2" '
#                            'style="vertical-align:middle"></a></div>\n'
#                            '</div></div>\n'
#                            '</div>\n'
#                            '\n',
#             'description_text': '---------- Forwarded message ---------\r\n'
#                                 "From: 'Zoom' via India IT Ops AV "
#                                 '<India-IT-Ops-AV@schrodinger.com>\r\n'
#                                 'Date: Tue, Mar 25, 2025 at 5:02\u202fPM\r\n'
#                                 'Subject: [Alert] Hyd - Therapeutics 8 Pax '
#                                 '(HYD-14-Hyd - Prime 8 Pax (8)\r\n'
#                                 '[BYOD, Google Meet, Zoom]) : Zoom room is '
#                                 'offline\r\n'
#                                 'To: <india-it-ops-av@schrodinger.com>\r\n'
#                                 '\r\n'
#                                 '\r\n'
#                                 'Dear Administrator,\r\n'
#                                 '\r\n'
#                                 'Room name: Hyd - Therapeutics 8 Pax '
#                                 '(HYD-14-Hyd - Prime 8 Pax (8) [BYOD,\r\n'
#                                 'Google Meet, Zoom])\r\n'
#                                 'Your Zoom Rooms status has changed: Zoom room '
#                                 'is offline.\r\n'
#                                 '\r\n'
#                                 'Thank you for choosing Zoom.\r\n'
#                                 '-The Zoom Team\r\n'
#                                 '\r\n'
#                                 '\r\n'
#                                 '-- \r\n'
#                                 '\r\n'
#                                 'Arudra TirupathiRao | Associate systems '
#                                 'Administrator\r\n'
#                                 '\r\n'
#                                 '\r\n'
#                                 'P: 9553412586\r\n'
#                                 '\r\n'
#                                 '[image: Schrödinger, Inc.] '
#                                 '<https://schrodinger.com/>\r\n'
#                                 '\r\n',
#             'due_by': '2025-04-14T07:12:33Z',
#             'email_config_id': 19000019114.0,
#             'fr_due_by': '2025-03-25T21:00:00Z',
#             'fr_escalated': False,
#             'fwd_emails': array([], dtype=object),
#             'group_id': 19000445066.0,
#             'id': 24699,
#             'is_escalated': False,
#             'item_category': None,
#             'priority': 1,
#             'reply_cc_emails': array([], dtype=object),
#             'requested_for_id': 19004188444,
#             'requester_id': 19004188444,
#             'responder_id': 19002382318.0,
#             'source': 1,
#             'spam': False,
#             'status': 5,
#             'sub_category': 'Zoom Room Controller - iPad',
#             'subject': 'Fwd: [Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - '
#                        'Prime 8 Pax (8) [BYOD, Google Meet, Zoom]) : Zoom room '
#                        'is offline',
#             'tasks_dependency_type': 0,
#             'to_emails': array(['IT Help <it-help@schrodinger.com>'], dtype=object),
#             'type': 'Incident',
#             'updated_at': '2025-04-03T09:37:33Z',
#             'workspace_id': 2}}
#
# Pretty print of 5th item in 'data' column (if exists):
# {'conversations': array([], dtype=object),
#  'export_version': '1.0',
#  'exported_at': '2025-06-28T03:15:36.026229',
#  'ticket': {'category': 'Software / Application',
#             'cc_emails': array([], dtype=object),
#             'created_at': '2025-03-26T19:26:51Z',
#             'custom_fields': {'business_impact': None,
#                               'change_number': None,
#                               'fedex_return_tracking': None,
#                               'fedex_tracking': None,
#                               'impacted_locations': None,
#                               'jira_url': None,
#                               'lf_on_behalf_of': None,
#                               'location': 'Remote',
#                               'major_incident_type': None,
#                               'msf_cause_code': array(['General Inquiry'], dtype=object),
#                               'msf_closure_code': array(['Solved (Permanently)'], dtype=object),
#                               'no_of_customers_impacted': None,
#                               'requested_date': None,
#                               'ticket_type': None,
#                               'time_zone': None,
#                               'transferred': None,
#                               'user_change_date': None,
#                               'user_change_email': None,
#                               'user_impact': None},
#             'deleted': False,
#             'department_id': 19000267440.0,
#             'description': '<div style="font-family: '
#                            '-apple-system,BlinkMacSystemFont,Segoe '
#                            'UI,Roboto,Helvetica Neue,Arial,sans-serif; '
#                            'font-size: 14px; "><div dir="ltr">Leah Stopped by '
#                            'and said she was receiving emails that her old '
#                            'computer hadnt been backed up</div></div>',
#             'description_text': 'Leah Stopped by and said she was receiving '
#                                 'emails that her old computer hadnt been '
#                                 'backed up',
#             'due_by': '2025-04-14T19:37:02Z',
#             'email_config_id': None,
#             'fr_due_by': '2025-03-27T19:26:51Z',
#             'fr_escalated': False,
#             'fwd_emails': array([], dtype=object),
#             'group_id': None,
#             'id': 24787,
#             'is_escalated': False,
#             'item_category': None,
#             'priority': 1,
#             'reply_cc_emails': array([], dtype=object),
#             'requested_for_id': 19002408049,
#             'requester_id': 19002408049,
#             'responder_id': 19001332955.0,
#             'source': 1,
#             'spam': False,
#             'status': 5,
#             'sub_category': 'Druva',
#             'subject': 'Druva email',
#             'tasks_dependency_type': 0,
#             'to_emails': None,
#             'type': 'Incident',
#             'updated_at': '2025-04-03T19:38:01Z',
#             'workspace_id': 2}}

# %%
print("\n--- PyArrow Direct Inspection ---")
try:
    # Read the Parquet schema directly
    parquet_schema = pq.read_schema(parquet_file_path)
    print("\nPyArrow Parquet Schema (detailed types including nested):")
    print(parquet_schema)
    # Look for 'struct' (for dictionaries) and 'list' (for arrays) types here.

    # Read the entire Parquet file into an Arrow Table
    arrow_table = pq.read_table(parquet_file_path)
    print(f"\nArrow Table loaded successfully. Rows: {arrow_table.num_rows}, Columns: {arrow_table.num_columns}")
    print("\nArrow Table Column Names:", arrow_table.column_names)

    # Access a specific column in PyArrow
    if 'data' in arrow_table.column_names:
        data_column = arrow_table.column('data')
        print(f"\nArrow Type of 'data' column: {data_column.type}")
        print("First value in 'data' column (as PyArrow Scalar):")
        print(data_column[0])
        # Convert to Python object for easier viewing
        print("\nFirst value in 'data' column (converted to Python object):")
        pprint.pprint(data_column[0].as_py())
    else:
        print("\n'data' column not found in Arrow Table.")

    # Inspect Parquet file metadata (e.g., number of row groups, compression)
    parquet_file = pq.ParquetFile(parquet_file_path)
    print("\nParquet File Metadata:")
    print(f"Number of Row Groups: {parquet_file.num_row_groups}")
    print(f"File Version: {parquet_file.metadata.format_version}")

    # You can loop through row groups for more detail, e.g.,
    # for i in range(parquet_file.num_row_groups):
    #     row_group_metadata = parquet_file.metadata.row_group(i)
    #     print(f"  Row Group {i}: Num Rows={row_group_metadata.num_rows}, Compressed Size={row_group_metadata.compressed_size}")
    #     for col_meta_idx in range(row_group_metadata.num_columns):
    #         col_meta = row_group_metadata.column(col_meta_idx)
    #         print(f"    Column {col_meta.path_in_schema}: Compression={col_meta.compression}")


except Exception as e:
    print(f"\nError during PyArrow direct inspection: {e}", file=sys.stderr)
    print("This could be due to a malformed Parquet file or a schema issue.")


print("\n--- Debugging complete ---")
# Out:
# --- PyArrow Direct Inspection ---
#
# PyArrow Parquet Schema (detailed types including nested):
# original_file_path: string
# original_filename: string
# data: struct<conversations: list<element: struct<attachments: list<element: struct<attachment_url: string, content_type: string, created_at: string, id: int64, name: string, size: int64, updated_at: string>>, bcc_emails: list<element: string>, body: string, body_text: string, cc_emails: list<element: string>, created_at: string, from_email: string, id: int64, incoming: bool, private: bool, source: int64, support_email: string, ticket_id: int64, to_emails: list<element: string>, updated_at: string, user_id: int64>>, export_version: string, exported_at: string, ticket: struct<category: string, cc_emails: list<element: string>, created_at: string, custom_fields: struct<business_impact: null, change_number: null, fedex_return_tracking: null, fedex_tracking: string, impacted_locations: null, jira_url: string, lf_on_behalf_of: int64, location: string, major_incident_type: null, msf_cause_code: list<element: string>, msf_closure_code: list<element: string>, no_of_customers_impacted: null, requested_date: string, ticket_type: string, time_zone: string, transferred: bool, user_change_date: string, user_change_email: string, user_impact: string>, deleted: bool, department_id: int64, description: string, description_text: string, due_by: string, email_config_id: int64, fr_due_by: string, fr_escalated: bool, fwd_emails: list<element: string>, group_id: int64, id: int64, is_escalated: bool, item_category: string, priority: int64, reply_cc_emails: list<element: string>, requested_for_id: int64, requester_id: int64, responder_id: int64, source: int64, spam: bool, status: int64, sub_category: string, subject: string, tasks_dependency_type: int64, to_emails: list<element: string>, type: string, updated_at: string, workspace_id: int64>>
#   child 0, conversations: list<element: struct<attachments: list<element: struct<attachment_url: string, content_type: string, created_at: string, id: int64, name: string, size: int64, updated_at: string>>, bcc_emails: list<element: string>, body: string, body_text: string, cc_emails: list<element: string>, created_at: string, from_email: string, id: int64, incoming: bool, private: bool, source: int64, support_email: string, ticket_id: int64, to_emails: list<element: string>, updated_at: string, user_id: int64>>
#       child 0, element: struct<attachments: list<element: struct<attachment_url: string, content_type: string, created_at: string, id: int64, name: string, size: int64, updated_at: string>>, bcc_emails: list<element: string>, body: string, body_text: string, cc_emails: list<element: string>, created_at: string, from_email: string, id: int64, incoming: bool, private: bool, source: int64, support_email: string, ticket_id: int64, to_emails: list<element: string>, updated_at: string, user_id: int64>
#           child 0, attachments: list<element: struct<attachment_url: string, content_type: string, created_at: string, id: int64, name: string, size: int64, updated_at: string>>
#               child 0, element: struct<attachment_url: string, content_type: string, created_at: string, id: int64, name: string, size: int64, updated_at: string>
#                   child 0, attachment_url: string
#                   child 1, content_type: string
#                   child 2, created_at: string
#                   child 3, id: int64
#                   child 4, name: string
#                   child 5, size: int64
#                   child 6, updated_at: string
#           child 1, bcc_emails: list<element: string>
#               child 0, element: string
#           child 2, body: string
#           child 3, body_text: string
#           child 4, cc_emails: list<element: string>
#               child 0, element: string
#           child 5, created_at: string
#           child 6, from_email: string
#           child 7, id: int64
#           child 8, incoming: bool
#           child 9, private: bool
#           child 10, source: int64
#           child 11, support_email: string
#           child 12, ticket_id: int64
#           child 13, to_emails: list<element: string>
#               child 0, element: string
#           child 14, updated_at: string
#           child 15, user_id: int64
#   child 1, export_version: string
#   child 2, exported_at: string
#   child 3, ticket: struct<category: string, cc_emails: list<element: string>, created_at: string, custom_fields: struct<business_impact: null, change_number: null, fedex_return_tracking: null, fedex_tracking: string, impacted_locations: null, jira_url: string, lf_on_behalf_of: int64, location: string, major_incident_type: null, msf_cause_code: list<element: string>, msf_closure_code: list<element: string>, no_of_customers_impacted: null, requested_date: string, ticket_type: string, time_zone: string, transferred: bool, user_change_date: string, user_change_email: string, user_impact: string>, deleted: bool, department_id: int64, description: string, description_text: string, due_by: string, email_config_id: int64, fr_due_by: string, fr_escalated: bool, fwd_emails: list<element: string>, group_id: int64, id: int64, is_escalated: bool, item_category: string, priority: int64, reply_cc_emails: list<element: string>, requested_for_id: int64, requester_id: int64, responder_id: int64, source: int64, spam: bool, status: int64, sub_category: string, subject: string, tasks_dependency_type: int64, to_emails: list<element: string>, type: string, updated_at: string, workspace_id: int64>
#       child 0, category: string
#       child 1, cc_emails: list<element: string>
#           child 0, element: string
#       child 2, created_at: string
#       child 3, custom_fields: struct<business_impact: null, change_number: null, fedex_return_tracking: null, fedex_tracking: string, impacted_locations: null, jira_url: string, lf_on_behalf_of: int64, location: string, major_incident_type: null, msf_cause_code: list<element: string>, msf_closure_code: list<element: string>, no_of_customers_impacted: null, requested_date: string, ticket_type: string, time_zone: string, transferred: bool, user_change_date: string, user_change_email: string, user_impact: string>
#           child 0, business_impact: null
#           child 1, change_number: null
#           child 2, fedex_return_tracking: null
#           child 3, fedex_tracking: string
#           child 4, impacted_locations: null
#           child 5, jira_url: string
#           child 6, lf_on_behalf_of: int64
#           child 7, location: string
#           child 8, major_incident_type: null
#           child 9, msf_cause_code: list<element: string>
#               child 0, element: string
#           child 10, msf_closure_code: list<element: string>
#               child 0, element: string
#           child 11, no_of_customers_impacted: null
#           child 12, requested_date: string
#           child 13, ticket_type: string
#           child 14, time_zone: string
#           child 15, transferred: bool
#           child 16, user_change_date: string
#           child 17, user_change_email: string
#           child 18, user_impact: string
#       child 4, deleted: bool
#       child 5, department_id: int64
#       child 6, description: string
#       child 7, description_text: string
#       child 8, due_by: string
#       child 9, email_config_id: int64
#       child 10, fr_due_by: string
#       child 11, fr_escalated: bool
#       child 12, fwd_emails: list<element: string>
#           child 0, element: string
#       child 13, group_id: int64
#       child 14, id: int64
#       child 15, is_escalated: bool
#       child 16, item_category: string
#       child 17, priority: int64
#       child 18, reply_cc_emails: list<element: string>
#           child 0, element: string
#       child 19, requested_for_id: int64
#       child 20, requester_id: int64
#       child 21, responder_id: int64
#       child 22, source: int64
#       child 23, spam: bool
#       child 24, status: int64
#       child 25, sub_category: string
#       child 26, subject: string
#       child 27, tasks_dependency_type: int64
#       child 28, to_emails: list<element: string>
#           child 0, element: string
#       child 29, type: string
#       child 30, updated_at: string
#       child 31, workspace_id: int64
#
# Arrow Table loaded successfully. Rows: 11364, Columns: 3
#
# Arrow Table Column Names: ['original_file_path', 'original_filename', 'data']
#
# Arrow Type of 'data' column: struct<conversations: list<element: struct<attachments: list<element: struct<attachment_url: string, content_type: string, created_at: string, id: int64, name: string, size: int64, updated_at: string>>, bcc_emails: list<element: string>, body: string, body_text: string, cc_emails: list<element: string>, created_at: string, from_email: string, id: int64, incoming: bool, private: bool, source: int64, support_email: string, ticket_id: int64, to_emails: list<element: string>, updated_at: string, user_id: int64>>, export_version: string, exported_at: string, ticket: struct<category: string, cc_emails: list<element: string>, created_at: string, custom_fields: struct<business_impact: null, change_number: null, fedex_return_tracking: null, fedex_tracking: string, impacted_locations: null, jira_url: string, lf_on_behalf_of: int64, location: string, major_incident_type: null, msf_cause_code: list<element: string>, msf_closure_code: list<element: string>, no_of_customers_impacted: null, requested_date: string, ticket_type: string, time_zone: string, transferred: bool, user_change_date: string, user_change_email: string, user_impact: string>, deleted: bool, department_id: int64, description: string, description_text: string, due_by: string, email_config_id: int64, fr_due_by: string, fr_escalated: bool, fwd_emails: list<element: string>, group_id: int64, id: int64, is_escalated: bool, item_category: string, priority: int64, reply_cc_emails: list<element: string>, requested_for_id: int64, requester_id: int64, responder_id: int64, source: int64, spam: bool, status: int64, sub_category: string, subject: string, tasks_dependency_type: int64, to_emails: list<element: string>, type: string, updated_at: string, workspace_id: int64>>
# First value in 'data' column (as PyArrow Scalar):
# [('conversations', []), ('export_version', '1.0'), ('exported_at', '2025-06-28T03:15:37.698894'), ('ticket', {'category': 'Conference Room', 'cc_emails': [], 'created_at': '2025-03-25T11:37:38Z', 'custom_fields': {'business_impact': None, 'change_number': None, 'fedex_return_tracking': None, 'fedex_tracking': None, 'impacted_locations': None, 'jira_url': None, 'lf_on_behalf_of': None, 'location': 'HYD', 'major_incident_type': None, 'msf_cause_code': ['Access Request'], 'msf_closure_code': ['Solved (Permanently)'], 'no_of_customers_impacted': None, 'requested_date': None, 'ticket_type': None, 'time_zone': None, 'transferred': None, 'user_change_date': None, 'user_change_email': None, 'user_impact': None}, 'deleted': False, 'department_id': 19000267440, 'description': '<div dir="ltr">\n<br><br><div>\n<div dir="ltr">---------- Forwarded message ---------<br>From: <strong dir="auto">\'Zoom\' via India IT Ops AV</strong> <span dir="auto">&lt;<a href="mailto:India-IT-Ops-AV@schrodinger.com" rel="noreferrer">India-IT-Ops-AV@schrodinger.com</a>&gt;</span><br>Date: Tue, Mar 25, 2025 at 5:02\u202fPM<br>Subject: [Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - Prime 8 Pax (8) [BYOD, Google Meet, Zoom]) : Zoom room is offline<br>To:  &lt;<a href="mailto:india-it-ops-av@schrodinger.com" rel="noreferrer">india-it-ops-av@schrodinger.com</a>&gt;<br>\n</div>\n<br><br>\n<div>\nDear Administrator,<br>\n<br>\nRoom name: Hyd - Therapeutics 8 Pax (HYD-14-Hyd - Prime 8 Pax (8) [BYOD, Google Meet, Zoom])<br>\nYour Zoom Rooms status has changed: Zoom room is offline.<br>\n<br>\nThank you for choosing Zoom.<br>\n-The Zoom Team\n</div>\n\n</div>\n<div><br></div>\n<div><br></div>\n<span>-- </span><br><div dir="ltr"><div dir="ltr">\n<div style="margin:0px 0px 1pt;font-family:Arial;font-size:12px;color:rgb(7,55,99);line-height:1.15">\n<span style="font-weight:bolder">Arudra TirupathiRao\xa0</span>| Associate systems Administrator</div>\n<div style="margin:0px 0px 1pt;font-family:Arial;font-size:12px;color:rgb(57,80,102);line-height:1.15"><br></div>\n<div style="margin:0px;font-family:Arial;font-size:12px;color:rgb(86,202,239);line-height:1.15">P:\xa0<a href="tel:9553412586" style="color:rgb(86,202,239);text-decoration:unset!important" target="_blank" rel="noreferrer">9553412586</a>\n</div>\n<div style="margin:0px 0px 1pt;font-family:Arial;font-size:12px;color:rgb(7,55,99);line-height:1.15"><a href="https://schrodinger.com/" style="color:rgb(13,110,253)" target="_blank" rel="noreferrer"><img src="https://s3.amazonaws.com/content.schrodinger.com/images/email_sig/logo.png" alt="Schrödinger, Inc." height="63.2" style="vertical-align:middle"></a></div>\n</div></div>\n</div>\n\n', 'description_text': "---------- Forwarded message ---------\r\nFrom: 'Zoom' via India IT Ops AV <India-IT-Ops-AV@schrodinger.com>\r\nDate: Tue, Mar 25, 2025 at 5:02\u202fPM\r\nSubject: [Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - Prime 8 Pax (8)\r\n[BYOD, Google Meet, Zoom]) : Zoom room is offline\r\nTo: <india-it-ops-av@schrodinger.com>\r\n\r\n\r\nDear Administrator,\r\n\r\nRoom name: Hyd - Therapeutics 8 Pax (HYD-14-Hyd - Prime 8 Pax (8) [BYOD,\r\nGoogle Meet, Zoom])\r\nYour Zoom Rooms status has changed: Zoom room is offline.\r\n\r\nThank you for choosing Zoom.\r\n-The Zoom Team\r\n\r\n\r\n-- \r\n\r\nArudra TirupathiRao | Associate systems Administrator\r\n\r\n\r\nP: 9553412586\r\n\r\n[image: Schrödinger, Inc.] <https://schrodinger.com/>\r\n\r\n", 'due_by': '2025-04-14T07:12:33Z', 'email_config_id': 19000019114, 'fr_due_by': '2025-03-25T21:00:00Z', 'fr_escalated': False, 'fwd_emails': [], 'group_id': 19000445066, 'id': 24699, 'is_escalated': False, 'item_category': None, 'priority': 1, 'reply_cc_emails': [], 'requested_for_id': 19004188444, 'requester_id': 19004188444, 'responder_id': 19002382318, 'source': 1, 'spam': False, 'status': 5, 'sub_category': 'Zoom Room Controller - iPad', 'subject': 'Fwd: [Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - Prime 8 Pax (8) [BYOD, Google Meet,  ...
#
# First value in 'data' column (converted to Python object):
# {'conversations': [],
#  'export_version': '1.0',
#  'exported_at': '2025-06-28T03:15:37.698894',
#  'ticket': {'category': 'Conference Room',
#             'cc_emails': [],
#             'created_at': '2025-03-25T11:37:38Z',
#             'custom_fields': {'business_impact': None,
#                               'change_number': None,
#                               'fedex_return_tracking': None,
#                               'fedex_tracking': None,
#                               'impacted_locations': None,
#                               'jira_url': None,
#                               'lf_on_behalf_of': None,
#                               'location': 'HYD',
#                               'major_incident_type': None,
#                               'msf_cause_code': ['Access Request'],
#                               'msf_closure_code': ['Solved (Permanently)'],
#                               'no_of_customers_impacted': None,
#                               'requested_date': None,
#                               'ticket_type': None,
#                               'time_zone': None,
#                               'transferred': None,
#                               'user_change_date': None,
#                               'user_change_email': None,
#                               'user_impact': None},
#             'deleted': False,
#             'department_id': 19000267440,
#             'description': '<div dir="ltr">\n'
#                            '<br><br><div>\n'
#                            '<div dir="ltr">---------- Forwarded message '
#                            '---------<br>From: <strong dir="auto">\'Zoom\' via '
#                            'India IT Ops AV</strong> <span dir="auto">&lt;<a '
#                            'href="mailto:India-IT-Ops-AV@schrodinger.com" '
#                            'rel="noreferrer">India-IT-Ops-AV@schrodinger.com</a>&gt;</span><br>Date: '
#                            'Tue, Mar 25, 2025 at 5:02\u202fPM<br>Subject: '
#                            '[Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - '
#                            'Prime 8 Pax (8) [BYOD, Google Meet, Zoom]) : Zoom '
#                            'room is offline<br>To:  &lt;<a '
#                            'href="mailto:india-it-ops-av@schrodinger.com" '
#                            'rel="noreferrer">india-it-ops-av@schrodinger.com</a>&gt;<br>\n'
#                            '</div>\n'
#                            '<br><br>\n'
#                            '<div>\n'
#                            'Dear Administrator,<br>\n'
#                            '<br>\n'
#                            'Room name: Hyd - Therapeutics 8 Pax (HYD-14-Hyd - '
#                            'Prime 8 Pax (8) [BYOD, Google Meet, Zoom])<br>\n'
#                            'Your Zoom Rooms status has changed: Zoom room is '
#                            'offline.<br>\n'
#                            '<br>\n'
#                            'Thank you for choosing Zoom.<br>\n'
#                            '-The Zoom Team\n'
#                            '</div>\n'
#                            '\n'
#                            '</div>\n'
#                            '<div><br></div>\n'
#                            '<div><br></div>\n'
#                            '<span>-- </span><br><div dir="ltr"><div '
#                            'dir="ltr">\n'
#                            '<div style="margin:0px 0px '
#                            '1pt;font-family:Arial;font-size:12px;color:rgb(7,55,99);line-height:1.15">\n'
#                            '<span style="font-weight:bolder">Arudra '
#                            'TirupathiRao\xa0</span>| Associate systems '
#                            'Administrator</div>\n'
#                            '<div style="margin:0px 0px '
#                            '1pt;font-family:Arial;font-size:12px;color:rgb(57,80,102);line-height:1.15"><br></div>\n'
#                            '<div '
#                            'style="margin:0px;font-family:Arial;font-size:12px;color:rgb(86,202,239);line-height:1.15">P:\xa0'
#                            '<a href="tel:9553412586" '
#                            'style="color:rgb(86,202,239);text-decoration:unset!important" '
#                            'target="_blank" rel="noreferrer">9553412586</a>\n'
#                            '</div>\n'
#                            '<div style="margin:0px 0px '
#                            '1pt;font-family:Arial;font-size:12px;color:rgb(7,55,99);line-height:1.15"><a '
#                            'href="https://schrodinger.com/" '
#                            'style="color:rgb(13,110,253)" target="_blank" '
#                            'rel="noreferrer"><img '
#                            'src="https://s3.amazonaws.com/content.schrodinger.com/images/email_sig/logo.png" '
#                            'alt="Schrödinger, Inc." height="63.2" '
#                            'style="vertical-align:middle"></a></div>\n'
#                            '</div></div>\n'
#                            '</div>\n'
#                            '\n',
#             'description_text': '---------- Forwarded message ---------\r\n'
#                                 "From: 'Zoom' via India IT Ops AV "
#                                 '<India-IT-Ops-AV@schrodinger.com>\r\n'
#                                 'Date: Tue, Mar 25, 2025 at 5:02\u202fPM\r\n'
#                                 'Subject: [Alert] Hyd - Therapeutics 8 Pax '
#                                 '(HYD-14-Hyd - Prime 8 Pax (8)\r\n'
#                                 '[BYOD, Google Meet, Zoom]) : Zoom room is '
#                                 'offline\r\n'
#                                 'To: <india-it-ops-av@schrodinger.com>\r\n'
#                                 '\r\n'
#                                 '\r\n'
#                                 'Dear Administrator,\r\n'
#                                 '\r\n'
#                                 'Room name: Hyd - Therapeutics 8 Pax '
#                                 '(HYD-14-Hyd - Prime 8 Pax (8) [BYOD,\r\n'
#                                 'Google Meet, Zoom])\r\n'
#                                 'Your Zoom Rooms status has changed: Zoom room '
#                                 'is offline.\r\n'
#                                 '\r\n'
#                                 'Thank you for choosing Zoom.\r\n'
#                                 '-The Zoom Team\r\n'
#                                 '\r\n'
#                                 '\r\n'
#                                 '-- \r\n'
#                                 '\r\n'
#                                 'Arudra TirupathiRao | Associate systems '
#                                 'Administrator\r\n'
#                                 '\r\n'
#                                 '\r\n'
#                                 'P: 9553412586\r\n'
#                                 '\r\n'
#                                 '[image: Schrödinger, Inc.] '
#                                 '<https://schrodinger.com/>\r\n'
#                                 '\r\n',
#             'due_by': '2025-04-14T07:12:33Z',
#             'email_config_id': 19000019114,
#             'fr_due_by': '2025-03-25T21:00:00Z',
#             'fr_escalated': False,
#             'fwd_emails': [],
#             'group_id': 19000445066,
#             'id': 24699,
#             'is_escalated': False,
#             'item_category': None,
#             'priority': 1,
#             'reply_cc_emails': [],
#             'requested_for_id': 19004188444,
#             'requester_id': 19004188444,
#             'responder_id': 19002382318,
#             'source': 1,
#             'spam': False,
#             'status': 5,
#             'sub_category': 'Zoom Room Controller - iPad',
#             'subject': 'Fwd: [Alert] Hyd - Therapeutics 8 Pax (HYD-14-Hyd - '
#                        'Prime 8 Pax (8) [BYOD, Google Meet, Zoom]) : Zoom room '
#                        'is offline',
#             'tasks_dependency_type': 0,
#             'to_emails': ['IT Help <it-help@schrodinger.com>'],
#             'type': 'Incident',
#             'updated_at': '2025-04-03T09:37:33Z',
#             'workspace_id': 2}}
#
# Parquet File Metadata:
# Number of Row Groups: 1
# File Version: 2.6
#
# --- Debugging complete ---
